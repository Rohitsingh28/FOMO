# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import datetime
#% matplotlib inline

# %%
Nifty_auto = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY Auto_Data.csv")
Nifty_Bank = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY Bank_Data.csv")
Nifty_Energy = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY Energy_Data.csv")
Nifty_Financial_serv = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY Financial Services_Data.csv")
Nifty_FMCG = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY FMCG_Data.csv")
Nifty_Infra = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY Infrastructure _Data.csv")
Nifty_IT = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY IT_Data.csv")
Nifty_Media = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY Media_Data.csv")
Nifty_Metal = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY Metal_Data.csv")
Nifty_Pharma = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY Pharma_Data.csv")
Nifty_Pvt_Bank = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY Private Bank_Data.csv")
Nifty_PSE = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY PSE _Data.csv")
Nifty_PSU_Bank = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY PSU Bank_Data.csv")
Nifty_Reality = pd.read_csv("C:\\Users\\Dell\\Downloads\\NIFTY Realty_Data.csv")

# %%
indicepanel = pd.DataFrame()
indicepanel['Nifty_auto'] = Nifty_auto['Close']
indicepanel['Nifty_Bank'] = Nifty_Bank['Close']
indicepanel['Nifty_Energy'] = Nifty_Energy['Close']
indicepanel['Nifty_Financial_serv'] = Nifty_Financial_serv['Close']
indicepanel['Nifty_FMCG'] = Nifty_FMCG['Close']
indicepanel['Nifty_Infra'] = Nifty_Infra['Close']
indicepanel['Nifty_IT'] = Nifty_IT['Close']
indicepanel['Nifty_Media'] = Nifty_Media['Close']
indicepanel['Nifty_Metal'] = Nifty_Metal['Close']
indicepanel['Nifty_Pharma'] = Nifty_Pharma['Close']
indicepanel['Nifty_Pvt_Bank'] = Nifty_Pvt_Bank['Close']
indicepanel['Nifty_PSE'] = Nifty_PSE['Close']
indicepanel['Nifty_PSU_Bank'] = Nifty_PSU_Bank['Close']
indicepanel['Nifty_Reality'] = Nifty_Reality['Close']
indicepanel.head()
# Out:
#    Nifty_auto  Nifty_Bank  Nifty_Energy  Nifty_Financial_serv  Nifty_FMCG  \
# 0     6856.90    28868.40      13419.05              13520.00    29138.90
# 1     6986.65    29177.05      13863.70              13636.95    29406.20
# 2     6938.85    28653.70      13876.65              13439.50    29223.75
# 3     6953.75    28815.35      13743.65              13472.75    29530.50
# 4     6895.00    27801.45      13342.60              13082.50    28937.00
#
#    Nifty_Infra  Nifty_IT  Nifty_Media  Nifty_Metal  Nifty_Pharma  \
# 0      2972.35  15427.65      1594.70      2197.60       7535.10
# 1      3044.80  15723.20      1647.65      2320.75       7920.60
# 2      3024.65  15864.30      1617.65      2304.30       8086.55
# 3      3014.70  15871.35      1606.30      2284.85       8146.00
# 4      2949.55  15663.45      1527.15      2183.90       8018.30
#
#    Nifty_Pvt_Bank  Nifty_PSE  Nifty_PSU_Bank  Nifty_Reality
# 0        15861.55    2675.70          1857.6         279.65
# ...

# %%
indicepanel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Nifty_auto            113 non-null    float64
#  1   Nifty_Bank            113 non-null    float64
#  2   Nifty_Energy          113 non-null    float64
#  3   Nifty_Financial_serv  113 non-null    float64
#  4   Nifty_FMCG            113 non-null    float64
#  5   Nifty_Infra           113 non-null    float64
#  6   Nifty_IT              113 non-null    float64
#  7   Nifty_Media           113 non-null    float64
#  8   Nifty_Metal           113 non-null    float64
#  9   Nifty_Pharma          113 non-null    float64
#  10  Nifty_Pvt_Bank        113 non-null    float64
#  11  Nifty_PSE             113 non-null    float64
#  12  Nifty_PSU_Bank        113 non-null    float64
#  13  Nifty_Reality         113 non-null    float64
# dtypes: float64(14)
# ...

# %%
(indicepanel/indicepanel.iloc[0]*100).plot(figsize = (19,10))
plt.ylabel('Return in percentage', size = 15)
# Out:
# Text(0, 0.5, 'Return in percentage')

# %%
indicepanel.head()
# Out:
#    Nifty_auto  Nifty_Bank  Nifty_Energy  Nifty_Financial_serv  Nifty_FMCG  \
# 0     6856.90    28868.40      13419.05              13520.00    29138.90
# 1     6986.65    29177.05      13863.70              13636.95    29406.20
# 2     6938.85    28653.70      13876.65              13439.50    29223.75
# 3     6953.75    28815.35      13743.65              13472.75    29530.50
# 4     6895.00    27801.45      13342.60              13082.50    28937.00
#
#    Nifty_Infra  Nifty_IT  Nifty_Media  Nifty_Metal  Nifty_Pharma  \
# 0      2972.35  15427.65      1594.70      2197.60       7535.10
# 1      3044.80  15723.20      1647.65      2320.75       7920.60
# 2      3024.65  15864.30      1617.65      2304.30       8086.55
# 3      3014.70  15871.35      1606.30      2284.85       8146.00
# 4      2949.55  15663.45      1527.15      2183.90       8018.30
#
#    Nifty_Pvt_Bank  Nifty_PSE  Nifty_PSU_Bank  Nifty_Reality
# 0        15861.55    2675.70          1857.6         279.65
# ...

# %%
Nifty_PSE.head()
# Out:
#         Date     Open     High      Low    Close
# 0  02-Mar-20  2768.95  2795.50  2652.90  2675.70
# 1  03-Mar-20  2701.75  2796.30  2700.05  2777.25
# 2  04-Mar-20  2779.15  2803.35  2734.55  2776.75
# 3  05-Mar-20  2793.65  2814.05  2754.10  2761.10
# 4  06-Mar-20  2665.55  2702.75  2641.00  2679.65

# %%
Nifty_PSE.tail()
# Out:
#           Date    Open     High      Low    Close
# 108  10-Aug-20  2519.7  2524.50  2501.55  2513.55
# 109  11-Aug-20  2528.8  2551.30  2513.55  2517.40
# 110  12-Aug-20  2514.9  2522.80  2497.20  2514.35
# 111  13-Aug-20  2518.8  2532.65  2503.85  2527.75
# 112  14-Aug-20  2544.0  2544.00  2492.40  2503.85
